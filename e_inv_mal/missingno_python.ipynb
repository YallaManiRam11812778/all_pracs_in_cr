# %%
import missingno
import pandas as pd
import numpy as np

dict = {'First Score':[100],
        'Second Score': [30],
        'Third Score':[np.nan]}

df = pd.DataFrame(dict)
missingno.bar(df, figsize=(5,5), fontsize=12)
# Out:
# <Axes: >
