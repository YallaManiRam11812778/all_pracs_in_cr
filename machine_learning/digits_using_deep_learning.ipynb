# %%
import tensorflow as tf
print(tf.__version__,">"*100)
mnist = tf.keras.datasets.mnist # 28X28 images of hand-written digits 0-9
(x_train, y_train), (x_test,y_test) = mnist.load_data()
# x_train = tf.keras.utils.normalize(x_train)
# y_train = tf.keras.utils.normalize(y_train)
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(10,activation=tf.nn.softmax))

model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])
# model.fit(x_train, y_train, epochs=3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import tensorflow as tf
#       2 print(tf.__version__,">"*100)
#       3 mnist = tf.keras.datasets.mnist # 28X28 images of hand-written digits 0-9
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
loss, accuracy = model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 0s 762us/step - loss: 93.5744 - accuracy: 0.1208

# %%
# try:
import matplotlib.pyplot as plt
plt.imshow(x_train[-1],cmap=plt.cm.binary)
# except Exception as e:
#     print(e)
# print(x_train[0])

# %%
model.save("trained_handwritten_model_deep_learning_keras.model")
# Out:
# INFO:tensorflow:Assets written to: trained_handwritten_model_deep_learning_keras.model/assets
# INFO:tensorflow:Assets written to: trained_handwritten_model_deep_learning_keras.model/assets

# %%
new_keras_model = tf.keras.models.load_model("trained_handwritten_model_deep_learning_keras.model")

# %%
predictions_are = new_keras_model.predict(x_train)
import numpy as np
print(np.argmax(predictions_are[-1]))
# Out:
# 1875/1875 [==============================] - 1s 774us/step
# 3

# %%
plt.imshow(x_train[-1])

# %%
import numpy as np
for i in range(0, len(predictions_are)):
    print(np.argmax(predictions_are[i]))
# Out:
# 7
# 2
# 1
# 0
# 4
# 1
# 4
# 9
# 5
# 9
# 0
# 6
# 9
# 0
# 1
# 5
# 9
# 7
# 8
# 4
# 9
# 6
# 6
# 5
# 4
# 0
# 7
# 4
# 0
# 1
# 3
# 1
# 3
# 4
# 7
# 2
# 7
# 1
# 2
# 1
# 1
# 7
# 4
# 2
# 3
# 5
# 1
# 2
# 4
# 4
# 6
# 3
# 5
# 5
# 6
# 0
# 4
# 1
# 9
# 5
# 7
# 8
# 9
# 3
# 7
# 9
# 6
# 4
# 3
# 0
# 7
# 0
# 2
# 9
# 1
# 7
# 3
# 2
# 9
# 7
# 7
# 6
# 2
# 7
# 8
# 4
# 7
# 3
# 6
# 1
# 3
# 6
# 9
# 5
# 1
# 4
# 1
# 7
# 6
# 9
# 6
# 0
# 5
# 4
# 3
# 9
# 2
# 1
# 9
# 4
# 8
# 7
# 3
# 9
# 7
# 4
# 4
# 4
# 9
# 2
# 5
# 4
# 7
# 6
# 7
# 9
# 0
# 5
# 8
# 5
# 6
# 6
# 5
# 7
# 8
# 1
# 0
# 1
# 6
# 4
# 6
# 7
# 3
# 1
# 7
# 1
# 8
# 2
# 0
# 4
# 9
# 8
# 5
# 5
# 1
# 5
# 6
# 0
# 3
# 4
# 4
# 6
# 5
# 4
# 6
# 5
# 4
# 5
# 1
# 4
# 4
# 7
# 2
# 3
# 2
# 7
# 1
# 8
# 1
# 8
# 1
# 8
# 5
# 0
# 8
# 9
# 2
# 5
# 0
# 1
# 1
# 1
# 0
# 9
# 0
# 3
# 1
# 6
# 4
# 2
# 3
# 6
# 1
# 1
# 1
# 3
# 9
# 5
# 2
# 9
# 4
# 5
# 9
# 3
# 9
# 0
# 3
# 6
# 5
# 5
# 7
# 2
# 2
# 7
# 1
# 2
# 8
# 4
# 1
# 7
# 3
# 3
# 8
# 8
# 7
# 9
# 2
# 2
# 4
# 1
# 5
# 8
# 8
# 7
# 2
# 3
# 0
# 2
# 4
# 2
# ...
